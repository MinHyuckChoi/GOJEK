# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import csv   

# To draw graph in notebook
# %matplotlib inline

# To create grid in graph 
plt.style.use('ggplot')
sns.set_palette("husl")

# %%
# Import data

problemB = pd.read_csv('problemB.csv')

# %%
problemB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 26 columns):
# booking_id                  248 non-null float64
# data_date                   248 non-null object
# booking_date                248 non-null object
# dispatch_time               248 non-null object
# closing_time                248 non-null object
# merchant_name               248 non-null object
# customer_id                 248 non-null float64
# customer_name               248 non-null object
# driver_id                   248 non-null float64
# driver_name                 248 non-null object
# shopping_estimated_price    248 non-null float64
# origin_longitude            248 non-null float64
# origin_latitude             248 non-null float64
# destination_longitude       248 non-null float64
# destination_latitude        248 non-null float64
# total_distance              248 non-null float64
# origin_note                 248 non-null object
# ...

# %%
problemB.describe()
# Out:
#          booking_id   customer_id     driver_id  shopping_estimated_price  \
# count  2.480000e+02  2.480000e+02  2.480000e+02                248.000000
# mean   8.318596e+08  2.477395e+08  3.646550e+08              36560.483871
# std    3.765402e+05  4.971410e+06  8.349551e+04               9639.471138
# min    8.302675e+08  2.302049e+08  3.644874e+08               7000.000000
# 25%    8.320118e+08  2.497476e+08  3.646403e+08              40000.000000
# 50%    8.320142e+08  2.498946e+08  3.646403e+08              40000.000000
# 75%    8.320158e+08  2.498957e+08  3.646403e+08              40000.000000
# max    8.321842e+08  2.499086e+08  3.649943e+08              68000.000000
#
#        origin_longitude  origin_latitude  destination_longitude  \
# count      2.480000e+02     2.480000e+02             248.000000
# mean       1.069663e+02    -6.336410e+00             106.845470
# std        3.844690e-13     3.915888e-14               0.062404
# ...

# %%
problemB.shape
# Out:
# (463, 26)

# %%
problemB.hist(figsize = (20,20))
plt.show()

# %%
sns.countplot(x="data_date", data=problemB)

# %%
figure, ((ax1)) = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,15)
b = sns.countplot(x="customer_id", data=problemB)
b.set_xticklabels(b.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, '230204944.0'),
#  Text(0, 0, '230246513.0'),
#  Text(0, 0, '231088298.0'),
#  Text(0, 0, '231157945.0'),
#  Text(0, 0, '231203329.0'),
#  Text(0, 0, '232147951.0'),
#  Text(0, 0, '232268509.0'),
#  Text(0, 0, '232423195.0'),
#  Text(0, 0, '232966002.0'),
#  Text(0, 0, '233148082.0'),
#  Text(0, 0, '233712406.0'),
#  Text(0, 0, '234038090.0'),
#  Text(0, 0, '234301391.0'),
#  Text(0, 0, '234930846.0'),
#  Text(0, 0, '234951373.0'),
#  Text(0, 0, '235994987.0'),
#  Text(0, 0, '236578487.0'),
#  Text(0, 0, '236586599.0'),
#  Text(0, 0, '236599065.0'),
#  Text(0, 0, '237832604.0'),
#  Text(0, 0, '238123874.0'),
#  Text(0, 0, '240574779.0'),
#  Text(0, 0, '240995104.0'),
#  Text(0, 0, '242236227.0'),
#  Text(0, 0, '242494516.0'),
#  Text(0, 0, '243006190.0'),
#  Text(0, 0, '243194030.0'),
#  Text(0, 0, '243641053.0'),
#  Text(0, 0, '244971608.0'),
#  Text(0, 0, '245177390.0'),
#  Text(0, 0, '245747904.0'),
#  Text(0, 0, '246632808.0'),
#  Text(0, 0, '247719507.0'),
# ...

# %%
figure, ((ax1)) = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,15)
b = sns.countplot(x="customer_name", data=problemB)
b.set_xticklabels(b.get_xticklabels(), rotation=15)
# Out:
# [Text(0, 0, 'wita'),
#  Text(0, 0, 'yanti'),
#  Text(0, 0, 'son'),
#  Text(0, 0, 'ani'),
#  Text(0, 0, 'sanah'),
#  Text(0, 0, 'yani'),
#  Text(0, 0, 'Alber'),
#  Text(0, 0, 'RUDI '),
#  Text(0, 0, 'Marwa'),
#  Text(0, 0, 'sugik'),
#  Text(0, 0, 'hana'),
#  Text(0, 0, 'hapsa'),
#  Text(0, 0, 'genta'),
#  Text(0, 0, 'arasy'),
#  Text(0, 0, 'rosa'),
#  Text(0, 0, 'Rayha'),
#  Text(0, 0, 'amel'),
#  Text(0, 0, 'agnes'),
#  Text(0, 0, 'agung'),
#  Text(0, 0, 'Azali'),
#  Text(0, 0, 'syifa'),
#  Text(0, 0, 'djauh'),
#  Text(0, 0, 'Arta'),
#  Text(0, 0, 'May R'),
#  Text(0, 0, 'nydia'),
#  Text(0, 0, 'Afiqa'),
#  Text(0, 0, 'Adity'),
#  Text(0, 0, 'IMAN '),
#  Text(0, 0, 'Adhir'),
#  Text(0, 0, 'hasan'),
#  Text(0, 0, 'mommy'),
#  Text(0, 0, 'ines'),
#  Text(0, 0, 'Rosia'),
#  Text(0, 0, 'Quinc'),
#  Text(0, 0, 'sonda'),
#  Text(0, 0, 'nidya'),
#  Text(0, 0, 'bule'),
#  Text(0, 0, 'dafa '),
#  Text(0, 0, 'Angri'),
#  Text(0, 0, 'cika '),
#  Text(0, 0, 'natha'),
#  Text(0, 0, 'Meita'),
# ...

# %%
figure, ((ax1)) = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,15)
b = sns.countplot(x="driver_id", data=problemB)
b.set_xticklabels(b.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, '364487363.0'),
#  Text(0, 0, '364491398.0'),
#  Text(0, 0, '364511542.0'),
#  Text(0, 0, '364514060.0'),
#  Text(0, 0, '364516183.0'),
#  Text(0, 0, '364517727.0'),
#  Text(0, 0, '364531832.0'),
#  Text(0, 0, '364532897.0'),
#  Text(0, 0, '364535582.0'),
#  Text(0, 0, '364535955.0'),
#  Text(0, 0, '364541746.0'),
#  Text(0, 0, '364547108.0'),
#  Text(0, 0, '364559858.0'),
#  Text(0, 0, '364564954.0'),
#  Text(0, 0, '364565312.0'),
#  Text(0, 0, '364589738.0'),
#  Text(0, 0, '364601559.0'),
#  Text(0, 0, '364640292.0'),
#  Text(0, 0, '364642254.0'),
#  Text(0, 0, '364653639.0'),
#  Text(0, 0, '364654290.0'),
#  Text(0, 0, '364729575.0'),
#  Text(0, 0, '364741921.0'),
#  Text(0, 0, '364748790.0'),
#  Text(0, 0, '364756720.0'),
#  Text(0, 0, '364784187.0'),
#  Text(0, 0, '364819069.0'),
#  Text(0, 0, '364820298.0'),
#  Text(0, 0, '364822190.0'),
#  Text(0, 0, '364822319.0'),
#  Text(0, 0, '364831718.0'),
#  Text(0, 0, '364867468.0'),
#  Text(0, 0, '364889798.0'),
# ...

# %%
figure, ((ax1)) = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,15)
b = sns.countplot(x="shopping_estimated_price", data=problemB)
b.set_xticklabels(b.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, '7000.0'),
#  Text(0, 0, '10000.0'),
#  Text(0, 0, '11000.0'),
#  Text(0, 0, '12000.0'),
#  Text(0, 0, '15000.0'),
#  Text(0, 0, '17000.0'),
#  Text(0, 0, '18000.0'),
#  Text(0, 0, '20000.0'),
#  Text(0, 0, '21000.0'),
#  Text(0, 0, '22000.0'),
#  Text(0, 0, '23000.0'),
#  Text(0, 0, '24000.0'),
#  Text(0, 0, '26000.0'),
#  Text(0, 0, '28000.0'),
#  Text(0, 0, '29000.0'),
#  Text(0, 0, '30000.0'),
#  Text(0, 0, '36000.0'),
#  Text(0, 0, '40000.0'),
#  Text(0, 0, '45000.0'),
#  Text(0, 0, '50000.0'),
#  Text(0, 0, '52000.0'),
#  Text(0, 0, '60000.0'),
#  Text(0, 0, '61000.0'),
#  Text(0, 0, '68000.0')]

# %%
figure, ((ax1)) = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,15)
b = sns.countplot(x="destination_address", data=problemB)
b.set_xticklabels(b.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'Jalan Raya Sawangan, Pancoran MAS, Kota Depok'),
#  Text(0, 0, 'Gang Masjid, Pancoran MAS, Kota Depok'),
#  Text(0, 0, 'Jalan Pitara Raya, Pancoran MAS, Kota Depok'),
#  Text(0, 0, 'Jalan Salak, Pancoran MAS, Kota Depok'),
#  Text(0, 0, 'Jalan Dewi Sartika, Pancoran MAS, Kota Depok'),
#  Text(0, 0, 'Jalan Boulevard Kota Wisata'),
#  Text(0, 0, 'Jalan Raya Ciangsana, Gunung Putri, Bogor'),
#  Text(0, 0, 'Jalan Calgary'),
#  Text(0, 0, 'Jalan Da Vinci, Gunung Putri, Bogor'),
#  Text(0, 0, 'Jalan West Covina 4'),
#  Text(0, 0, 'Jalan Belut Raya, Bekasi Selatan, Kota Bekasi'),
#  Text(0, 0, 'Jalan Oman, Jatiasih, Kota Bekasi'),
#  Text(0, 0, 'Jalan Puri Delta Raya, Gunung Putri, Bogor'),
#  Text(0, 0, 'Ciangsana, Gn. Putri, Bogor, Jawa Barat 16968, Indonesia'),
#  Text(0, 0, 'Jalan Nusa Indah Raya, Gunung Putri, Bogor'),
#  Text(0, 0, 'Jalan Vila Nusa Indah 3, Gunung Putri, Bogor'),
#  Text(0, 0, 'Jalan Nurul Huda, Bantargebang, Kota Bekasi'),
# ...

# %%
figure, ((ax1)) = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,15)
b = sns.countplot(x="driver_name", data=problemB)
b.set_xticklabels(b.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'HARRY'),
#  Text(0, 0, 'Surdi'),
#  Text(0, 0, 'Marve'),
#  Text(0, 0, 'Sento'),
#  Text(0, 0, 'Agus '),
#  Text(0, 0, 'Amrul'),
#  Text(0, 0, 'Herwa'),
#  Text(0, 0, 'Jimmy'),
#  Text(0, 0, 'Adu'),
#  Text(0, 0, 'Hasan'),
#  Text(0, 0, 'Wasri'),
#  Text(0, 0, 'Supri'),
#  Text(0, 0, 'Herma'),
#  Text(0, 0, 'Sanan'),
#  Text(0, 0, 'Sumar'),
#  Text(0, 0, 'Enggo'),
#  Text(0, 0, 'Tatan'),
#  Text(0, 0, 'M. Al'),
#  Text(0, 0, 'Ricky'),
#  Text(0, 0, 'Kurni'),
#  Text(0, 0, 'Lukma'),
#  Text(0, 0, 'Tri K'),
#  Text(0, 0, 'Yul A'),
#  Text(0, 0, 'Bamba'),
#  Text(0, 0, 'Asma '),
#  Text(0, 0, 'Syams'),
#  Text(0, 0, 'Ade E'),
#  Text(0, 0, 'Darso'),
#  Text(0, 0, 'Eko S'),
#  Text(0, 0, 'Suhen'),
#  Text(0, 0, 'Angga'),
#  Text(0, 0, 'Djadj'),
#  Text(0, 0, 'Nevre'),
#  Text(0, 0, 'Tri W'),
#  Text(0, 0, 'Toris'),
#  Text(0, 0, 'Johan'),
#  Text(0, 0, 'Darto'),
#  Text(0, 0, 'Dani '),
#  Text(0, 0, 'Dedi ')]
